# %%
import pandas as pd
import numpy as np
from datetime import timedelta
#from ics import Calendar,Event

# %%
## Word of caution
## Pandas do not sort properly when time is in the format of AM/PM. It thinks its a string/object.
## Thus sort everything based on 24 hr format and convert it into 12 Hr format at the end only.

# %%
data = pd.read_excel("merged_v4.xlsx", sheet_name=None)
data.keys()
# Out:
# dict_keys(['Parallel', 'Publishing Schedule', 'July11230AM working good', 'merged_v4', 'Invited'])

# %%
df = data['July11230AM working good']

# %%
import os, sys
sys.version
# Out:
# '3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 10:07:17) [Clang 14.0.6 ]'

# %%
df['Start Time'].unique()
# Out:
# array([datetime.time(22, 15), datetime.time(22, 45), datetime.time(23, 0),
#        datetime.time(0, 0), datetime.time(0, 15), datetime.time(0, 30),
#        datetime.time(0, 45), datetime.time(1, 0), datetime.time(1, 15),
#        datetime.time(1, 30), datetime.time(1, 45), datetime.time(2, 0),
#        datetime.time(2, 15), datetime.time(2, 30), datetime.time(4, 0),
#        datetime.time(4, 30), datetime.time(4, 45), datetime.time(5, 0),
#        datetime.time(5, 15), datetime.time(5, 30), datetime.time(5, 45),
#        datetime.time(6, 15), datetime.time(6, 30), datetime.time(6, 45),
#        datetime.time(7, 0), datetime.time(7, 15), datetime.time(9, 0),
#        datetime.time(9, 30), datetime.time(10, 0), datetime.time(11, 0),
#        datetime.time(11, 30), datetime.time(11, 45), datetime.time(12, 0),
#        datetime.time(12, 15), datetime.time(12, 30), datetime.time(14, 0),
#        datetime.time(14, 30), datetime.time(14, 45), datetime.time(15, 0),
#        datetime.time(15, 15), datetime.time(15, 30),
#        datetime.time(15, 45), datetime.time(16, 30),
#        datetime.time(16, 45), datetime.time(17, 0), datetime.time(17, 15),
#        datetime.time(17, 30), datetime.time(17, 45),
#        datetime.time(21, 30), datetime.time(21, 45), datetime.time(22, 0),
#        datetime.time(22, 30), datetime.time(23, 15),
#        datetime.time(23, 30), datetime.time(23, 45), datetime.time(8, 45),
#        datetime.time(10, 15), datetime.time(10, 30),
#        datetime.time(10, 45), datetime.time(11, 15),
#        datetime.time(14, 15), datetime.time(16, 15),
#        datetime.time(19, 30), datetime.time(20, 0), datetime.time(20, 15),
#        datetime.time(20, 30), datetime.time(19, 45),
#        datetime.time(20, 45), datetime.time(21, 15), datetime.time(9, 15),
#        datetime.time(9, 45)], dtype=object)

# %%
#df = pd.read_csv("merged_v3.csv")
## Assign AbstractID
df['abstract_id'] = ['ANPA2024-N000'+str(x) for x in range(1,len(df)+1)]
df.columns
# Out:
# Index(['timestamp', 'presenter', 'email', 'method', 'affiliation',
#        'manuscript', 'session', 'title', 'abstract', 'invited',
#        'corresponding', 'understand', 'coauthors', 'coemail', 'DATE-TIME',
#        'Start Date', 'Start Time', 'End Date', 'End Time', 'Unnamed: 19',
#        'Unnamed: 20', 'abstract_id'],
#       dtype='object')

# %%
cols_needed = ['presenter', 'method', 'affiliation', 'manuscript', 'session',
       'title', 'abstract', 'invited',  'Start Date', 'Start Time', 'End Date',
       'End Time', 'abstract_id']
df = df[cols_needed]
df.head()
# Out:
#                        presenter method  \
# 0                   Registration    CDP
# 1             Om Prakash Niroula    CDP
# 2  Narayan Prasad Chapagain, PhD    CDP
# 3                 Roshan Chalise    CDP
# 4               Santosh Dhungana    CDP
#
#                                          affiliation manuscript  \
# 0                                                NaN        NaN
# 1  Central Department of Physics, Tribhuvan Unive...        NaN
# 2  Department of Physics, Amrit Campus, Tribhuvan...        Yes
# 3  Central Department of Physics, Tribhuvan Unive...        Yes
# 4                               Tribhuvan University         No
#
#                                              session  \
# 0                                                NaN
# 1                                            Welcome
# 2  Astronomy /Space Science /Cosmo Science/ Atmos...
# 3      Atomic, Molecular, Optical and Plasma Physics
# 4      Atomic, Molecular, Optical and Plasma Physics
#
#                                                title  \
# 0                                                NaN
# 1                Welcome message by Department Chair
# 2  Space Weather at Low-Latitudes and Prospects o...
# 3  Development and Characterization of Gliding Ar...
# 4  Electrical and Optical Characterization of Kni...
#
#                                             abstract      invited Start Date  \
# 0                                                NaN          NaN 2024-07-18
# 1                                                NaN      Welcome 2024-07-18
# 2  Space is the ultimate high ground from which a...      Plenary 2024-07-18
# 3  In this work, we present the development of an...  Contributed 2024-07-19
# 4  GAD is an auto-oscillating discharge that star...  Contributed 2024-07-19
#
#   Start Time   End Date  End Time     abstract_id
# 0   22:15:00 2024-07-18  22:45:00  ANPA2024-N0001
# 1   22:45:00 2024-07-18  23:00:00  ANPA2024-N0002
# 2   23:00:00 2024-07-19  00:00:00  ANPA2024-N0003
# 3   00:00:00 2024-07-19  00:15:00  ANPA2024-N0004
# 4   00:15:00 2024-07-19  00:30:00  ANPA2024-N0005

# %%
df.shape
# Out:
# (145, 13)

# %%
df.head(1)
# Out:
#       presenter method affiliation manuscript session title abstract invited  \
# 0  Registration    CDP         NaN        NaN     NaN   NaN      NaN     NaN
#
#   Start Date Start Time   End Date  End Time     abstract_id
# 0 2024-07-18   22:15:00 2024-07-18  22:45:00  ANPA2024-N0001

# %%
## Need to create schedule based on Division, and then two more based on location (CDP and Fayetteville)

# %% [markdown]
# ## Generate HTML for individual Symposia Page

# %%
df.columns
# Out:
# Index(['presenter', 'method', 'affiliation', 'manuscript', 'session', 'title',
#        'abstract', 'invited', 'Start Date', 'Start Time', 'End Date',
#        'End Time', 'abstract_id'],
#       dtype='object')

# %%
df['method'].value_counts(dropna=False)
# Out:
# method
# Virtual         76
# CDP             23
# Poster          22
# Fayetteville    18
# NaN              5
# BOTH             1
# Name: count, dtype: int64

# %%
df.loc[df['method'].isnull()]
# Out:
#        presenter method affiliation manuscript session title abstract invited  \
# 6          Break    NaN         NaN        NaN     NaN   NaN      NaN     NaN
# 35  Poster+Lunch    NaN         NaN        NaN     NaN   NaN      NaN     NaN
# 41         Break    NaN         NaN        NaN     NaN   NaN      NaN     NaN
# 84         Break    NaN         NaN        NaN     NaN   NaN      NaN     NaN
# 91         Lunch    NaN         NaN        NaN     NaN   NaN      NaN     NaN
#
#    Start Date Start Time   End Date  End Time      abstract_id
# 6  2024-07-19   00:45:00 2024-07-19  01:00:00   ANPA2024-N0007
# 35 2024-07-19   02:30:00 2024-07-19  04:00:00  ANPA2024-N00036
# 41 2024-07-19   05:30:00 2024-07-19  05:45:00  ANPA2024-N00042
# 84 2024-07-20   10:45:00 2024-07-20  11:00:00  ANPA2024-N00085
# 91 2024-07-20   12:30:00 2024-07-20  14:00:00  ANPA2024-N00092

# %%
df.loc[df['method']=="BOTH"]
# Out:
#    presenter method affiliation manuscript           session title abstract  \
# 99      ANPA   BOTH         NaN        NaN  Business Meeting   NaN      NaN
#
#    invited Start Date Start Time   End Date  End Time       abstract_id
# 99     NaN 2024-07-20   16:15:00 2024-07-20  17:45:00  ANPA2024-N000100

# %%
df = df.rename(columns={"invited":"Type",
                       "session":"division"})

# %%
df['Type'].value_counts(dropna = False)
# Out:
# Type
# Contributed    103
# Poster          22
# Invited          9
# NaN              7
# Welcome          2
# Plenary          2
# Name: count, dtype: int64

# %%
df.loc[df['Type'].isnull()] ## All good
# Out:
#        presenter method affiliation manuscript          division title  \
# 0   Registration    CDP         NaN        NaN               NaN   NaN
# 6          Break    NaN         NaN        NaN               NaN   NaN
# 35  Poster+Lunch    NaN         NaN        NaN               NaN   NaN
# 41         Break    NaN         NaN        NaN               NaN   NaN
# 84         Break    NaN         NaN        NaN               NaN   NaN
# 91         Lunch    NaN         NaN        NaN               NaN   NaN
# 99          ANPA   BOTH         NaN        NaN  Business Meeting   NaN
#
#    abstract Type Start Date Start Time   End Date  End Time       abstract_id
# 0       NaN  NaN 2024-07-18   22:15:00 2024-07-18  22:45:00    ANPA2024-N0001
# 6       NaN  NaN 2024-07-19   00:45:00 2024-07-19  01:00:00    ANPA2024-N0007
# 35      NaN  NaN 2024-07-19   02:30:00 2024-07-19  04:00:00   ANPA2024-N00036
# 41      NaN  NaN 2024-07-19   05:30:00 2024-07-19  05:45:00   ANPA2024-N00042
# 84      NaN  NaN 2024-07-20   10:45:00 2024-07-20  11:00:00   ANPA2024-N00085
# 91      NaN  NaN 2024-07-20   12:30:00 2024-07-20  14:00:00   ANPA2024-N00092
# 99      NaN  NaN 2024-07-20   16:15:00 2024-07-20  17:45:00  ANPA2024-N000100

# %%
## I don't need all these breaks. Will drop them.
df_v2 = df.loc[~df['Type'].isnull()]
df_v2.isnull().sum()
# Out:
# presenter      0
# method         0
# affiliation    1
# manuscript     1
# division       0
# title          0
# abstract       2
# Type           0
# Start Date     0
# Start Time     0
# End Date       0
# End Time       0
# abstract_id    0
# dtype: int64

# %%
df_v2.shape
# Out:
# (138, 13)

# %%
df_v2[df_v2["affiliation"].isnull()]
# Out:
#          presenter        method affiliation manuscript  \
# 87  Dipendra Dahal  Fayetteville         NaN         No
#
#                                          division  \
# 87  Atomic, Molecular, Optical and Plasma Physics
#
#                                                 title  \
# 87  Resonance peak position tuning in Fabry Perot ...
#
#                                              abstract         Type Start Date  \
# 87  Making use of Maxwell’s equation, we have deri...  Contributed 2024-07-20
#
#    Start Time   End Date  End Time      abstract_id
# 87   11:30:00 2024-07-20  11:45:00  ANPA2024-N00088

# %%
df_v2[df_v2["abstract"].isnull()]
# Out:
#              presenter        method  \
# 1   Om Prakash Niroula           CDP
# 79       Daniel Autrey  Fayetteville
#
#                                           affiliation manuscript division  \
# 1   Central Department of Physics, Tribhuvan Unive...        NaN  Welcome
# 79                      Fayetteville State University         No  Welcome
#
#                                   title abstract     Type Start Date  \
# 1   Welcome message by Department Chair      NaN  Welcome 2024-07-18
# 79  Welcome message by Department Chair      NaN  Welcome 2024-07-20
#
#    Start Time   End Date  End Time      abstract_id
# 1    22:45:00 2024-07-18  23:00:00   ANPA2024-N0002
# 79   08:45:00 2024-07-20  09:00:00  ANPA2024-N00080

# %%
## Ok, all looks good.
df = df_v2

# %%
df.division.value_counts(dropna=False)
# Out:
# division
# Condensed Matter Physics and Material Science                   55
# Biological, Medical, Soft Matter and Chemical Physics           19
# Astronomy /Space Science /Cosmo Science/ Atmospheric Physics    16
# Atomic, Molecular, Optical and Plasma Physics                   14
# Applied and Industrial Physics                                   9
# Data Science, Quantum Computing, Artificial Intelligence         9
# Physics Education Research                                       8
# High Energy, Particle, and Nuclear Physics                       6
# Welcome                                                          2
# Name: count, dtype: int64

# %%
df.division.value_counts(dropna=False).sum()
# Out:
# 138

# %%
df.Type.value_counts(dropna=False)
# Out:
# Type
# Contributed    103
# Poster          22
# Invited          9
# Welcome          2
# Plenary          2
# Name: count, dtype: int64

# %%
df[df.Type=="Invited"]
# Out:
#                  presenter   method  \
# 36         Chiranjib Mitra      CDP
# 42        Ram Prasad Regmi      CDP
# 48   Madan Lamichhane, PhD  Virtual
# 51             Rudra KAFLE  Virtual
# 57             Binod K Rai  Virtual
# 100              Chuyu Liu  Virtual
# 110           Ganesh Chand  Virtual
# 119   Pushpa Raj Pudasaini  Virtual
# 142   Ganapathi Subramania  Virtual
#
#                                            affiliation manuscript  \
# 36   Indian Institute of Science Education and Rese...         No
# 42   National Atmospheric Resource and Environmenta...         No
# 48                                                FICO        Yes
# 51                     Worcester Polytechnic Institute        Yes
# 57                  Savannah River National Laboratory         No
# 100                            Brookhaven National Lab         No
# 110                 Washington University in St. Louis         No
# 119                       Samsung Austin Semiconductor         No
# 142                       Sandia National Laboratories         No
#
#                                               division  \
# 36       Condensed Matter Physics and Material Science
# 42   Astronomy /Space Science /Cosmo Science/ Atmos...
# 48   Data Science, Quantum Computing, Artificial In...
# 51                          Physics Education Research
# 57       Condensed Matter Physics and Material Science
# 100         High Energy, Particle, and Nuclear Physics
# 110  Biological, Medical, Soft Matter and Chemical ...
# 119                     Applied and Industrial Physics
# 142      Atomic, Molecular, Optical and Plasma Physics
#
#                                                  title  \
# 36   Topological Photo-current and magnetization co...
# 42   Air Pollution Transport and Formation of Pollu...
# 48   Physicist's Journey to Machine Learning Fraud ...
# 51   Integration of interactive multimedia to physi...
# 57   Binary Actinide Oxides: Synthesis, Crystal Str...
# 100  History and Future of accelerator development ...
# 110  AI and computational neuroimaging for brain he...
# 119  Advanced Semiconductor Technologies: Current S...
# 142             Light manipulation with nanostructures
#
#                                               abstract     Type Start Date  \
# 36   Optical control of helicity-dependent photocur...  Invited 2024-07-19
# 42   Unacceptable levels of air pollution in and ar...  Invited 2024-07-19
# 48   The transition from a career in physics to one...  Invited 2024-07-19
# 51   Multimedia communication refers to more than o...  Invited 2024-07-19
# 57   Actinides, with their distinctive electronic c...  Invited 2024-07-19
# 100  This talk gives a brief history on particle ac...  Invited 2024-07-20
# 110  Imaging modalities, such as magnetic resonance...  Invited 2024-07-20
# 119  The first part of the talk will discuss non-co...  Invited 2024-07-20
# 142  Photonic crystals, metamaterials and metasurfa...  Invited 2024-07-21
#
#     Start Time   End Date  End Time       abstract_id
# 36    04:00:00 2024-07-19  04:30:00   ANPA2024-N00037
# 42    05:45:00 2024-07-19  06:15:00   ANPA2024-N00043
# 48    09:00:00 2024-07-19  09:30:00   ANPA2024-N00049
# 51    11:00:00 2024-07-19  11:30:00   ANPA2024-N00052
# 57    14:00:00 2024-07-19  14:30:00   ANPA2024-N00058
# 100   19:30:00 2024-07-20  20:00:00  ANPA2024-N000101
# 110   21:15:00 2024-07-20  21:45:00  ANPA2024-N000111
# 119   22:45:00 2024-07-20  23:15:00  ANPA2024-N000120
# 142   10:45:00 2024-07-21  11:15:00  ANPA2024-N000143

# %%
df['Start Date'].value_counts()
# Out:
# Start Date
# 2024-07-19    73
# 2024-07-20    46
# 2024-07-21    17
# 2024-07-18     2
# Name: count, dtype: int64

# %%
 pd.to_datetime(df['Start Date'],format=('%Y-%M-%d'))
# Out:
# 1     2024-07-18
# 2     2024-07-18
# 3     2024-07-19
# 4     2024-07-19
# 5     2024-07-19
#          ...
# 140   2024-07-21
# 141   2024-07-21
# 142   2024-07-21
# 143   2024-07-21
# 144   2024-07-21
# Name: Start Date, Length: 138, dtype: datetime64[ns]

# %%
## Everything looks OK. Now creating date_time columns.
df['Date/Time']= df['Start Date'].astype(str)+' '+df['Start Time'].astype(str)
df.head(2)
# Out:
#                        presenter method  \
# 1             Om Prakash Niroula    CDP
# 2  Narayan Prasad Chapagain, PhD    CDP
#
#                                          affiliation manuscript  \
# 1  Central Department of Physics, Tribhuvan Unive...        NaN
# 2  Department of Physics, Amrit Campus, Tribhuvan...        Yes
#
#                                             division  \
# 1                                            Welcome
# 2  Astronomy /Space Science /Cosmo Science/ Atmos...
#
#                                                title  \
# 1                Welcome message by Department Chair
# 2  Space Weather at Low-Latitudes and Prospects o...
#
#                                             abstract     Type Start Date  \
# 1                                                NaN  Welcome 2024-07-18
# 2  Space is the ultimate high ground from which a...  Plenary 2024-07-18
#
#   Start Time   End Date  End Time     abstract_id            Date/Time
# 1   22:45:00 2024-07-18  23:00:00  ANPA2024-N0002  2024-07-18 22:45:00
# 2   23:00:00 2024-07-19  00:00:00  ANPA2024-N0003  2024-07-18 23:00:00

# %%
df['Start Time'].apply
# Out:
# <bound method Series.apply of 1      22:45:00
# 2      23:00:00
# 3      00:00:00
# 4      00:15:00
# 5      00:30:00
#          ...
# 140    10:00:00
# 141    10:15:00
# 142    10:45:00
# 143    11:15:00
# 144    11:30:00
# Name: Start Time, Length: 138, dtype: object>

# %%
parse(df['Date/Time'].iloc[0])
# Out:
# datetime.datetime(2024, 7, 18, 22, 45)

# %%
from dateutil.parser import parse

# %%
#df['Date/Time'].apply(parse)

# %%
#df['Date/Time'] = 
#pd.to_datetime(df['Date/Time'],format=('%Y-%m-%d  %H:%M:%S'))

# %%
## Everything looks OK. Now creating date_time columns.
df['Date/Time']= df['Start Date'].astype(str)+' '+df['Start Time'].astype(str)
df['Date/Time'] = pd.to_datetime(df['Date/Time'],format=('%Y-%m-%d  %H:%M:%S'))
df['Date/Time'] = [x.round('T') for x in df['Date/Time']]
df["Nepal Date/Time"]=df['Date/Time']+timedelta(hours=9.75)
df['Nepal Date/Time'] = [x.round('T') for x in df['Nepal Date/Time']]
df = df.sort_values(by="Date/Time")
# Out:
# /var/folders/f1/4671s3vx3jv4g4hs5j3v582w0000gn/T/ipykernel_76266/2294710601.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df['Date/Time'] = [x.round('T') for x in df['Date/Time']]
# /var/folders/f1/4671s3vx3jv4g4hs5j3v582w0000gn/T/ipykernel_76266/2294710601.py:6: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df['Nepal Date/Time'] = [x.round('T') for x in df['Nepal Date/Time']]

# %%
df["Author_I"]=np.where(df['Type']=="Invited",df["presenter"]+" (Invited)",df["presenter"])
df.loc[df['method']=="Virtual",'CDP/FYT/Virtual']="Virtual Presentation"
df.loc[df['method']=="Poster",'CDP/FYT/Virtual']="Poster Presentation"
df.loc[df['method'].isin(["CDP"]),'CDP/FYT/Virtual']="In-Person Presentation, CDP"
df.loc[df['method'].isin(["Fayetteville"]),'CDP/FYT/Virtual']="In-Person Presentation, Fayetteville"

# %%
df[df['CDP/FYT/Virtual'].isnull()]
# Out:
# Empty DataFrame
# Columns: [presenter, method, affiliation, manuscript, division, title, abstract, Type, Start Date, Start Time, End Date, End Time, abstract_id, Date/Time, Nepal Date/Time, Author_I, CDP/FYT/Virtual]
# Index: []

# %%
# df['Date/Time']=df['Date/Time'].dt.strftime('%Y/%m/%d %I:%M %p')
# df['Nepal Date/Time']=df['Nepal Date/Time'].dt.strftime('%Y/%m/%d %I:%M %p')

# %%
df['method'].value_counts(dropna=False)
# Out:
# method
# Virtual         76
# CDP             22
# Poster          22
# Fayetteville    18
# Name: count, dtype: int64

# %%
df.division.value_counts(dropna = False)
# Out:
# division
# Condensed Matter Physics and Material Science                   55
# Biological, Medical, Soft Matter and Chemical Physics           19
# Astronomy /Space Science /Cosmo Science/ Atmospheric Physics    16
# Atomic, Molecular, Optical and Plasma Physics                   14
# Applied and Industrial Physics                                   9
# Data Science, Quantum Computing, Artificial Intelligence         9
# Physics Education Research                                       8
# High Energy, Particle, and Nuclear Physics                       6
# Welcome                                                          2
# Name: count, dtype: int64

# %%
df_data=df.loc[df['division'].str.contains('Data Science')].sort_values(by='Date/Time')
df_PER=df.loc[df['division'].str.contains('Physics Education')].sort_values(by='Date/Time')
df_Condensed=df.loc[df['division'].str.contains('Condensed Matter')].sort_values(by='Date/Time')
df_Bio=df.loc[df['division'].str.contains('Biological,')].sort_values(by='Date/Time')
df_Plasma=df.loc[df['division'].str.contains('Atomic,')].sort_values(by='Date/Time')
df_HEP=df.loc[df['division'].str.contains('High Energy')].sort_values(by='Date/Time')
df_Astro=df.loc[df['division'].str.contains('Astronomy')].sort_values(by='Date/Time')
df_Applied=df.loc[df['division'].str.contains('Applied and')].sort_values(by='Date/Time')

## HTMLs based on location
df_CDP = df.loc[df['method'].str.contains('CDP|Poster')].sort_values(by='Date/Time')
df_FSU = df.loc[df['method'].str.contains('Fayetteville')].sort_values(by='Date/Time')

# %%
df_data.shape, df_PER.shape, df_Condensed.shape,df_Bio.shape,df_Plasma.shape, df_HEP.shape,df_Astro.shape,df_Applied.shape, df_CDP.shape, df_FSU.shape
# Out:
# ((9, 17),
#  (8, 17),
#  (55, 17),
#  (19, 17),
#  (14, 17),
#  (6, 17),
#  (16, 17),
#  (9, 17),
#  (44, 17),
#  (18, 17))

# %%
df_data.dtypes
# Out:
# presenter                  object
# method                     object
# affiliation                object
# manuscript                 object
# division                   object
# title                      object
# abstract                   object
# Type                       object
# Start Date         datetime64[ns]
# Start Time                 object
# End Date           datetime64[ns]
# End Time                   object
# abstract_id                object
# Date/Time          datetime64[ns]
# Nepal Date/Time    datetime64[ns]
# Author_I                   object
# CDP/FYT/Virtual            object
# dtype: object

# %%
df_Astro.sort_values(by="presenter")
# Out:
#                          presenter        method  \
# 129                  Aayush Gautam       Virtual
# 130                    Bhairab Ale       Virtual
# 131            Bishwas L. Shrestha       Virtual
# 43                 Lok Nath Sharma           CDP
# 44              Madhu Sudan Paudel           CDP
# 132                   Nabin Gurung       Virtual
# 94                   Nabin Malakar  Fayetteville
# 2    Narayan Prasad Chapagain, PhD           CDP
# 128                  Pradip Poudel       Virtual
# 45            Prakash Man Shrestha           CDP
# 133             Prem kumari katwal       Virtual
# 46              Purna Jyoti Shakya           CDP
# 42                Ram Prasad Regmi           CDP
# 47                Sanjay Lal Karna           CDP
# 90                      Sanjib K C  Fayetteville
# 134            Sujan Prasad Gautam       Virtual
#
#                                            affiliation manuscript  \
# 129    Department of Astronomy, University of Virginia         No
# 130                      Central Department of Physics        Yes
# 131                               Princeton University         No
# 43                                Tribhuvan University        Yes
# 44   Department of Physics, Tri-Chandra Multiple Ca...        Yes
# 132                               Tribhuvan University        Yes
# 94                          Worcester State University        Yes
# 2    Department of Physics, Amrit Campus, Tribhuvan...        Yes
# 128                              MSc Student at CDP,TU        Yes
# 45                            Patan Multiple Camus, TU        Yes
# 133                                                 TU        Yes
# 46                                Tribhuvan University        Yes
# 42   National Atmospheric Resource and Environmenta...         No
# 47   Central Department of Physics, Tribhuvan Unive...        Yes
# 90                            Georgia State University         No
# 134                    UAH Department of Space Science        Yes
#
#                                               division  \
# 129  Astronomy /Space Science /Cosmo Science/ Atmos...
# 130  Astronomy /Space Science /Cosmo Science/ Atmos...
# 131  Astronomy /Space Science /Cosmo Science/ Atmos...
# 43   Astronomy /Space Science /Cosmo Science/ Atmos...
# 44   Astronomy /Space Science /Cosmo Science/ Atmos...
# 132  Astronomy /Space Science /Cosmo Science/ Atmos...
# 94   Astronomy /Space Science /Cosmo Science/ Atmos...
# 2    Astronomy /Space Science /Cosmo Science/ Atmos...
# 128  Astronomy /Space Science /Cosmo Science/ Atmos...
# 45   Astronomy /Space Science /Cosmo Science/ Atmos...
# 133  Astronomy /Space Science /Cosmo Science/ Atmos...
# 46   Astronomy /Space Science /Cosmo Science/ Atmos...
# 42   Astronomy /Space Science /Cosmo Science/ Atmos...
# 47   Astronomy /Space Science /Cosmo Science/ Atmos...
# 90   Astronomy /Space Science /Cosmo Science/ Atmos...
# 134  Astronomy /Space Science /Cosmo Science/ Atmos...
#
#                                                  title  \
# 129  Gradual cluster formation: protoplanetary disk...
# 130  Analysis of Cross-Correlation of Bz and Pc4 du...
# 131  Suprathermal Hydrogen Pickup Ion Tails in the ...
# 43   Ionospheric variations during the geomagnetic ...
# 44   Seasonal Tropopause Dynamics over Nepal from 2...
# 132  DUST COLOR TEMPERATURE AND MASS AROUND PERSEUS...
# 94   Information to Action Using Air Pollution data...
# 2    Space Weather at Low-Latitudes and Prospects o...
# 128  Correlation Analysis of Solar Wind Parameters ...
# 45   Temporal variability of Solar Radiation and At...
# 133                         Space travel SST 6 Mission
# 46   Magnetospheric Pc5 pulsation generated by inte...
# 42   Air Pollution Transport and Formation of Pollu...
# 47   Photocurrent Behavior in Sunceco PV Cell Modul...
# 90   Space Radiation in Earth Environment with Radi...
# 134  Solar wind turbulence anisotropy evolution in ...
#
#                                               abstract         Type  \
# 129  The crowded environment of star clusters shape...  Contributed
# 130  This study delves into the southward interplan...  Contributed
# 131  Interstellar Pickup ions (PUIs) are created by...  Contributed
# 43   The reconnection between the Interplanetary Ma...  Contributed
# 44   ABSTRACT\nGlobal Navigtion and Satellite Syste...  Contributed
# 132  In this work, dust properties around the NGC-1...  Contributed
# 94   We will present a case study of Nepal, where a...  Contributed
# 2    Space is the ultimate high ground from which a...      Plenary
# 128  For more than a decade, scientists have studie...  Contributed
# 45   Population growth and industrialization effect...  Contributed
# 133  Space travel has long been a realm of fascinat...  Contributed
# 46   We investigate magnetospheric Ultra low freque...  Contributed
# 42   Unacceptable levels of air pollution in and ar...      Invited
# 47   The aim of this study is to explore how the ph...  Contributed
# 90   Monitoring and analyzing the radiation environ...  Contributed
# 134  In this work, we studied the evolution of anis...  Contributed
#
#     Start Date Start Time   End Date  End Time       abstract_id  \
# 129 2024-07-21   09:00:00 2024-07-21  09:15:00  ANPA2024-N000130
# 130 2024-07-21   09:15:00 2024-07-21  09:30:00  ANPA2024-N000131
# 131 2024-07-21   09:30:00 2024-07-21  09:45:00  ANPA2024-N000132
# 43  2024-07-19   06:15:00 2024-07-19  06:30:00   ANPA2024-N00044
# 44  2024-07-19   06:30:00 2024-07-19  06:45:00   ANPA2024-N00045
# 132 2024-07-21   09:45:00 2024-07-21  10:00:00  ANPA2024-N000133
# 94  2024-07-20   14:30:00 2024-07-20  14:45:00   ANPA2024-N00095
# 2   2024-07-18   23:00:00 2024-07-19  00:00:00    ANPA2024-N0003
# 128 2024-07-21   08:45:00 2024-07-21  09:00:00  ANPA2024-N000129
# 45  2024-07-19   06:45:00 2024-07-19  07:00:00   ANPA2024-N00046
# 133 2024-07-21   10:00:00 2024-07-21  10:15:00  ANPA2024-N000134
# 46  2024-07-19   07:00:00 2024-07-19  07:15:00   ANPA2024-N00047
# 42  2024-07-19   05:45:00 2024-07-19  06:15:00   ANPA2024-N00043
# 47  2024-07-19   07:15:00 2024-07-19  07:30:00   ANPA2024-N00048
# 90  2024-07-20   12:15:00 2024-07-20  12:30:00   ANPA2024-N00091
# 134 2024-07-21   10:15:00 2024-07-21  10:30:00  ANPA2024-N000135
#
#               Date/Time     Nepal Date/Time                       Author_I  \
# 129 2024-07-21 09:00:00 2024-07-21 18:45:00                  Aayush Gautam
# 130 2024-07-21 09:15:00 2024-07-21 19:00:00                    Bhairab Ale
# 131 2024-07-21 09:30:00 2024-07-21 19:15:00            Bishwas L. Shrestha
# 43  2024-07-19 06:15:00 2024-07-19 16:00:00                Lok Nath Sharma
# 44  2024-07-19 06:30:00 2024-07-19 16:15:00             Madhu Sudan Paudel
# 132 2024-07-21 09:45:00 2024-07-21 19:30:00                   Nabin Gurung
# 94  2024-07-20 14:30:00 2024-07-21 00:15:00                  Nabin Malakar
# 2   2024-07-18 23:00:00 2024-07-19 08:45:00  Narayan Prasad Chapagain, PhD
# 128 2024-07-21 08:45:00 2024-07-21 18:30:00                  Pradip Poudel
# 45  2024-07-19 06:45:00 2024-07-19 16:30:00           Prakash Man Shrestha
# 133 2024-07-21 10:00:00 2024-07-21 19:45:00             Prem kumari katwal
# 46  2024-07-19 07:00:00 2024-07-19 16:45:00             Purna Jyoti Shakya
# 42  2024-07-19 05:45:00 2024-07-19 15:30:00     Ram Prasad Regmi (Invited)
# 47  2024-07-19 07:15:00 2024-07-19 17:00:00               Sanjay Lal Karna
# 90  2024-07-20 12:15:00 2024-07-20 22:00:00                     Sanjib K C
# 134 2024-07-21 10:15:00 2024-07-21 20:00:00            Sujan Prasad Gautam
#
#                           CDP/FYT/Virtual
# 129                  Virtual Presentation
# 130                  Virtual Presentation
# 131                  Virtual Presentation
# 43            In-Person Presentation, CDP
# 44            In-Person Presentation, CDP
# 132                  Virtual Presentation
# 94   In-Person Presentation, Fayetteville
# 2             In-Person Presentation, CDP
# 128                  Virtual Presentation
# 45            In-Person Presentation, CDP
# 133                  Virtual Presentation
# 46            In-Person Presentation, CDP
# 42            In-Person Presentation, CDP
# 47            In-Person Presentation, CDP
# 90   In-Person Presentation, Fayetteville
# 134                  Virtual Presentation

# %%
prepend="""
<html>
<head>
<style>
#anpatable {
  font-family: "Trebuchet MS", Arial, Helvetica, sans-serif;
  border-collapse: collapse;
  width: 100%;
}

#anpatable td, #anpatable th {
  border: 1px solid #ddd;
  padding: 8px;
}

#anpatable tr:{background-color: #fff;}
#anpatable tr:nth-child(odd) {background-color: #D5DBdb;}
#anpatable tr:nth-child(even) {background-color: #e5e8e8;}

#anpatable tr:hover {background-color: #f8f9f9;}

#anpatable th {
  padding-top: 8px;
  padding-bottom: 8px;
  text-align: left;
  background-color: #4CAF50;
  color: white;
  width: 83px;
}

</style>
</head>
<body>
<h3> Please look below for detailed schedule. </h3></br>

	<table border="1" cellspacing="0" id="anpatable" cellpadding="2" width="680">
    <tbody>

"""


postpend="""
</tbody>
</table>

</body>
</html>

"""

# %%
df.head()
# Out:
#                        presenter method  \
# 1             Om Prakash Niroula    CDP
# 2  Narayan Prasad Chapagain, PhD    CDP
# 3                 Roshan Chalise    CDP
# 4               Santosh Dhungana    CDP
# 5          Devendra Raj Upadhyay    CDP
#
#                                          affiliation manuscript  \
# 1  Central Department of Physics, Tribhuvan Unive...        NaN
# 2  Department of Physics, Amrit Campus, Tribhuvan...        Yes
# 3  Central Department of Physics, Tribhuvan Unive...        Yes
# 4                               Tribhuvan University         No
# 5  Central Department of Physics, Tribhuvan Unive...        Yes
#
#                                             division  \
# 1                                            Welcome
# 2  Astronomy /Space Science /Cosmo Science/ Atmos...
# 3      Atomic, Molecular, Optical and Plasma Physics
# 4      Atomic, Molecular, Optical and Plasma Physics
# 5         High Energy, Particle, and Nuclear Physics
#
#                                                title  \
# 1                Welcome message by Department Chair
# 2  Space Weather at Low-Latitudes and Prospects o...
# 3  Development and Characterization of Gliding Ar...
# 4  Electrical and Optical Characterization of Kni...
# 5  Attenuation of Photons, Neutrons, and Heavy Io...
#
#                                             abstract         Type Start Date  \
# 1                                                NaN      Welcome 2024-07-18
# 2  Space is the ultimate high ground from which a...      Plenary 2024-07-18
# 3  In this work, we present the development of an...  Contributed 2024-07-19
# 4  GAD is an auto-oscillating discharge that star...  Contributed 2024-07-19
# 5  The present theoretical and simulation work in...  Contributed 2024-07-19
#
#   Start Time   End Date  End Time     abstract_id           Date/Time  \
# 1   22:45:00 2024-07-18  23:00:00  ANPA2024-N0002 2024-07-18 22:45:00
# 2   23:00:00 2024-07-19  00:00:00  ANPA2024-N0003 2024-07-18 23:00:00
# 3   00:00:00 2024-07-19  00:15:00  ANPA2024-N0004 2024-07-19 00:00:00
# 4   00:15:00 2024-07-19  00:30:00  ANPA2024-N0005 2024-07-19 00:15:00
# 5   00:30:00 2024-07-19  00:45:00  ANPA2024-N0006 2024-07-19 00:30:00
#
#       Nepal Date/Time                       Author_I  \
# 1 2024-07-19 08:30:00             Om Prakash Niroula
# 2 2024-07-19 08:45:00  Narayan Prasad Chapagain, PhD
# 3 2024-07-19 09:45:00                 Roshan Chalise
# 4 2024-07-19 10:00:00               Santosh Dhungana
# 5 2024-07-19 10:15:00          Devendra Raj Upadhyay
#
#                CDP/FYT/Virtual
# 1  In-Person Presentation, CDP
# 2  In-Person Presentation, CDP
# 3  In-Person Presentation, CDP
# 4  In-Person Presentation, CDP
# 5  In-Person Presentation, CDP

# %%
df.isnull().sum()
# Out:
# presenter          0
# method             0
# affiliation        1
# manuscript         1
# division           0
# title              0
# abstract           2
# Type               0
# Start Date         0
# Start Time         0
# End Date           0
# End Time           0
# abstract_id        0
# Date/Time          0
# Nepal Date/Time    0
# Author_I           0
# CDP/FYT/Virtual    0
# dtype: int64

# %%
df[df['abstract'].isnull()]
# Out:
#              presenter        method  \
# 1   Om Prakash Niroula           CDP
# 79       Daniel Autrey  Fayetteville
#
#                                           affiliation manuscript division  \
# 1   Central Department of Physics, Tribhuvan Unive...        NaN  Welcome
# 79                      Fayetteville State University         No  Welcome
#
#                                   title abstract     Type Start Date  \
# 1   Welcome message by Department Chair      NaN  Welcome 2024-07-18
# 79  Welcome message by Department Chair      NaN  Welcome 2024-07-20
#
#    Start Time   End Date  End Time      abstract_id           Date/Time  \
# 1    22:45:00 2024-07-18  23:00:00   ANPA2024-N0002 2024-07-18 22:45:00
# 79   08:45:00 2024-07-20  09:00:00  ANPA2024-N00080 2024-07-20 08:45:00
#
#        Nepal Date/Time            Author_I  \
# 1  2024-07-19 08:30:00  Om Prakash Niroula
# 79 2024-07-20 18:30:00       Daniel Autrey
#
#                          CDP/FYT/Virtual
# 1            In-Person Presentation, CDP
# 79  In-Person Presentation, Fayetteville

# %%
def prep_list(df):
    df = df.sort_values(by="Date/Time")
    df['Date/Time']=df['Date/Time'].dt.strftime('%Y/%m/%d %I:%M %p')
    df['Nepal Date/Time']=df['Nepal Date/Time'].dt.strftime('%Y/%m/%d %I:%M %p')
    Names_L= df['Author_I'].values
    title_L = df['title'].values
    affiliations_L = df['affiliation'].values
    abstract_L = df['abstract'].values
    abstract_n_L=df['abstract_id'].values
    Date_L=df['Date/Time'].astype(str).to_list()
    Date_L_N=df['Nepal Date/Time'].astype(str).to_list()
    Location_L = df['CDP/FYT/Virtual'].values
    return Names_L,affiliations_L,title_L,abstract_L,abstract_n_L,Date_L,Date_L_N, Location_L

# %%
prep_list(df_data)
# Out:
# (array(['Keshab Chaudhary, Dipendra Prasad Kalauni', 'Gokarna Banjade',
#         'Ambika Shahi', 'Aatiz Ghimire', 'Pratiksha Khanal',
#         'Pratima Khadka', 'Madan Lamichhane, PhD (Invited)',
#         'Dipak Rimal and Puskar Chapagain', 'Prajwol Lamichhane'],
#        dtype=object),
#  array(['Central Department of Physics , Tribhuvan University',
#         'Patan multiple campus',
#         'Central Department of Physics, Tribhuvan University, Kirtipur 44613, Kathmandu, Nepal',
#         'Tribhuvan University',
#         'Central Department of Physics, Tribhuvan University, Kirtipur 44613, Kathmandu, Nepal',
#         'Central Department of Physics, Tribhuvan University, Kirtipur 44613 Kathmandu ,Nepal',
#         'FICO',
#         'Benchmark Education Company, NewYork, NY, 10801 and bSouthern Arkansas University, Magnolia, AR, 71753',
#         'University of North Florida'], dtype=object),
#  array(['Machine Learning Driven Formation Energy and Lattice Parameter Prediction of Full Heusler Alloys: X2YZ',
#         "PREDICTION OF NEPAL'S 2021 EARTHQUAKE TREND USING SCALED INPUT IN A 4-LAYER LSTM MODEL.",
#         'Prediction of Lattice Parameter and Formation Energy of Cubic Semi-Heusler Alloys',
#         'Deep Learning Technique for Forest Fire Detection using Satellite Imagery',
#         'Predicting the Lattice Parameters of Transition Metal Halides - MXn via Machine Learning',
#         "Machine Learning Driven Prediction of Formation Energy and Band Gap of AxMyM'zO6 Oxides",
#         "Physicist's Journey to Machine Learning Fraud Prevention Scientist",
#         'Can AI Solve Physics Problems? Evaluating Efficacy of AI Models in Solving Higher Secondary Physics Exam Problems: A Comparative Study',
#         'Comparative Analysis of ChatGPT, Bard, and LLaMA on Medical Prompts using the MedQuAD Dataset'],
#        dtype=object),
#  array(["\nMachine learning, a part of both AI and data science, aims to enable machines to recognize patterns and generate decisions or predictions without requiring explicit programming. This work is based on the application of supervised learning in material science, utilizing machine learning as a useful tool for quickly identifying new materials and predicting their features. To predict the essential formation energy and lattice parameter, two supervised learning regression approaches within machine learning—random forest regression and gaussian process regression—have been used. In this study, the formation energy and lattice parameter of 140 full Heusler compounds were predicted by selecting 24 features of cubic structures with an 80% and 20% train-test split. Features such as volume, atomic radii, atomic mass, electro-negativity, lattice angle, band gap, formation energy, covalent radii, density, total magnetization, number of atoms, etc. were employed to predict the lattice parameter of cubic Heusler compounds (X2YZ). Model performance was evaluated using evaluation criteria such as mean squared error (MSE), mean absolute error (MAE), and R-squared (R2). After using both models, the obtained values for formation energy were as follows: Random Forest Regression—R2: 0.658, MSE: 0.011, MAE: 0.091, Gaussian Process Regression—R-squared: 0.734, MSE: 0.246, MAE: 0.396, indicating the GPR's higher accuracy. Similarly, for lattice parameter prediction, GPR demonstrated lower MSE (0.0023) and MAE (0.0396) values compared to RFR (MSE: 0.0025, MAE: 0.0423), with a slightly higher R-Square value (GPR: 0.9768, RFR: 0.9744), suggesting better overall goodness of fit. This study highlights the success of both RFR and GPR models in predicting lattice parameters and formation energy. It emphasises the potential of machine learning to efficiently and cost-effectively explore significant phase spaces in the search for new materials. \n\nKeywords: Formation Energy, Lattice parameter, Machine learning, Heusler compound, Random Forest Regression (RFR), Gaussian Process Regression (GPR), R-squared (coefficient of correlation), Mean square error (MSE), Mean absolute error (MAE).",
#         'Earthquake prediction is a critical field of study in Nepal due to its susceptibility to seismic activity caused by the energy released during plate movements. In this work, we use the LSTM model and advanced computer programs to analyze earthquake data and find trends. We utilize a deep neural network approach to enhance prediction accuracy. The dataset used from May 4, 1964, to May 23, 2023, was obtained from the USGS (United States Geological Survey) catalog of magnitude Mw ≥ 4. In this work, we aimed to predict earthquakes and trends around the year 2021 using data from a series of past earthquakes. A dataset of 1094 data points was used,with 88 for training and 1020 for testing. The primary focus was on earthquake event 1040, which occurred on May 18, 2021. The trained model is then used to predict the future trend of\nearthquakes. We consider four features like magnitude, time interval (in days), longitude, and latitude, and we find the best-fit model from the Kerus tuner-coded Python program. The program is executed multiple times, with each run corresponding to a specific number of epochs ranging from 100 to 1500. We observed that training the model with a larger number of epochs improved the\nprediction accuracy for the longitude, latitude, time interval, and magnitude features. Specifically, we observed that during epoch 1000, the prediction for longitude, latitude, time interval, and\nmagnitude of observed data tends to match with test data and is better as compared with other epochs. Reviewing the graph and its data, it becomes clear that errors are significantly lower during\nepoch 1000, as supported by the analysis of mean square error and mean absolute error.',
#         'Materials advancement is the propelling forces for present-day science and technology. In recent years, machine learning (ML) models are becoming popular in the field of materials research due to their remarkable precision at low computational cost. Notably, semi-Heusler alloys are getting attention due to their applications in thermoelectric, topological, shape memory as well as spintronics. In this work, we apply ML models to predict the lattice parameter and formation energies of selected semi-Heusler alloys XYZ (where X and Y are transition elements, and Z is a main group element) using dataset sources from materials project database. We predict the lattice parameters of 145 cubic semi-Heusler alloys using 24 features through regression models, specifically, Random Forest Regression (RFR) and Gaussian Process Regression (GPR). Subsequently, the labelled datasets were split into training and testing sets in the ratio of 80:20 for both the lattice parameter and formation energy prediction. A feature versus contribution barplot was created to show the contribution level of each parameter for predicting results. Assessing the model’s performance, we computed R-square, mean square error, and mean absolute error for RFR (GPR) models. Our findings suggest that GPR out performs RFR in predicting the lattice parameter, while RFR predicts the formation energy of cubic semi-Heusler alloys better. Furthermore, a heatmap shows the correlation between the actual data and the predicted data. This study demonstrates the developing predictive models using machine learning in materials science which enables deeper understanding of lattice parameter and formation energies.',
#         'Forest fire is one of the major causes of air pollution in Nepal, which also an fueling agent to climate change. To detect and identify forest fire is not an easy task in dense and isolated forest. To overcome this problem, we suggest a deep learning-based model to detect forest fire using satellite imagery. \n\nThe satellite image in this research is extracted from different opensource satellite data products such as Sentinenal-2 and Landsat Satellites. These data products contain multiple hyper-spectral band images, where we require only Red, Blue and Green Band Images. These images are then converted into True color Images. The Images containing the Forest Fire are then annotated manually with the help of label studio. This data is passed to Convolutional Neural Network to learn the forest fire features within the Satellite Imagery. This will detect fire, smoke and burnt areas in this Satellite Imagery. The dataset made for this purpose is split into 80-20 and made validation split to check the accuracy and performance of the model. ',
#         'Transition metal halides have been studied extensively because of their wide range of tunable electrical, magnetic, and topological properties that come from their unique crystal structure. Knowing lattice parameters, a building block of every crystal structure, enriches filtering materials properties like structure stability, electronic structure, magnetic ordering, and thus materials discovery. Here, we present machine learning models: Random Forest Regression (RFR) and Gradient Boosting Regression (GBR) for predicting lattice parameters (a,b,c) of transition metal halides -  Mxn with 238 samples based on the properties of their constituent atoms. The metrics R2 score and mean absolute error (MAE) are used for validation of model performance yielding the overall values 0.80±0.09(0.82±0.14) and 1.33±0.64(1.12±0.35) using RFR(GBR) respectively. We have observed that the predictive strengths of both models are quite comparable but as a whole,  GBR model is found to be more favorable than RFR. These findings are expected to be useful to experimentalist and theorist in characterizing and studying various properties of Mxn system.',
#         "Machine learning (ML) is an efficient method in the discovery of new materials due to its lower computational costs as compared to conventional density functional theory (DFT) and laboratory trials. In this work, we are using ML approach to predict the formation energy and band gap of AxMyM'zO6 (x=1,2,3 & y,z=1,2 ; y+z=3) perovskite material. A dataset of 350 compounds is collected with following features: lattice parameter, band gap, formation energy, total magnetization, energy above hull, density, and periodic table properties. We are using four ML models: Random forest (RF) regressor, Gradient boosting regressor (GBR), Support vector regression (SVR) and CatBoost regressor (CBR). Root mean squared error (RMSE) and R-squared value are evaluated to determine the performance of different models. The contribution of different features for formation energy and band gap prediction are also plotted from RF model. It is found that CBR model has achieved maximum performance in prediction with R-squared and RMSE: (0.83 and 0.41) and (0.44 and 0.69) for formation energy and band gap respectively. The properties of materials depends significantly on the magnitude of band gap. Formation energy is a determining factor of material's stability and synthesizability. So, ML can be used to assist DFT calculations for material discovery and its applications. \n\nKeywords: Machine learning, Formation energy, Band gap, RF, CBR.",
#         'The transition from a career in physics to one focused on machine learning for fraud prevention in financial systems represents a compelling narrative of interdisciplinary exploration and professional evolution. This abstract offers insights into this journey, highlighting the unique perspectives, challenges, and opportunities that physicists encounter when venturing into the realm of solving the real-world problem of fraud prevention through the machine learning model.\nWe physicists possess a diverse skill set encompassing advanced mathematical techniques, computational modeling, and a deep understanding of complex systems dynamics. As they pivot towards addressing the intricate challenges of fraud detection and prevention, physicists leverage their analytical prowess to uncover patterns, anomalies, and underlying structures within vast datasets of financial transactions.\nThis also includes the methodologies that physicists can employ for transitioning to machine learning scientists, emphasizing integrating physics principles into algorithmic design and model development. Drawing parallels between concepts in statistical mechanics, network theory, and quantum mechanics, physicists can craft innovative approaches to identify fraudulent activities with heightened accuracy and efficiency.\nFurthermore, this also explores the pivotal role of interdisciplinary collaboration in facilitating this career transition. Physicists engaging with data science, cybersecurity, and finance experts should gain domain-specific knowledge and refine their understanding of fraud dynamics in financial ecosystems. Through collaborative efforts, physicists can enhance their ability to translate theoretical insights into practical, real-world solutions that mitigate risks and safeguard financial institutions and consumers.\nThis also reflects on the personal and professional growth experienced by physicists navigating this transition. From acquiring new technical skills and domain expertise to embracing challenges and cultivating adaptability, the journey from physicist to machine learning fraud prevention scientist fosters a spirit of continual learning and innovation.\nIn conclusion, this underscores the significance of interdisciplinary collaboration and the potential for cross-pollinating ideas between physics and machine learning in addressing real-world challenges such as fraud prevention. By embarking on this career transition, physicists can contribute their unique perspectives and analytical rigor to advancing the state-of-the-art in fraud detection and prevention, ultimately strengthening the resilience of financial systems in an increasingly digital age.\n',
#         'The rapid advancement in the field of Generative Artificial Intelligence (AI) powered by large language models (LLMs) has expanded their application in diverse technical fields. While these models excel in various complex natural language processing tasks, they still lack the robust reasoning ability required to solve advanced mathematics and physics problems. Despite their current limitation, their adoption in higher education in physics and other technical fields is rising. In this project, we assessed the ability of various state-of-the-art proprietary and open-source AI models to solve Physics exam problems, specifically the board exam of class 12 of HSEB of Nepal. To achieve the goal, we employed a zero-shot prompting technique to generate solutions from the different LLMs and evaluated these solutions by the subject matter experts. In this talk, we will provide a brief overview of the underlying architecture of these models and compare the performance of different models as evaluated by human experts. Additionally, we will also discuss the risks and benefits of their use in higher education.',
#         'This research conducts a comparative analysis of various AI language models—ChatGPT, Bard, and LLaMA—focusing on their responses to medical prompts related to conditions such as Cancer, Senior Health, Bodily Pain, and Cardiovascular diseases. The study aims to evaluate the accuracy, comprehensiveness, and appropriateness of the generated responses using the MedQuAD dataset. A standardized set of medical prompts is used to query each model, and responses are analyzed both qualitatively and quantitatively using syntactic and semantic similarities against manually curated answers. Additionally, the generative factor of these AI models is tested by identifying the most frequently used keywords in their responses. The findings highlight the strengths and weaknesses of each model in handling complex medical information and offer insights into their potential utility and limitations in the healthcare domain. This project is crucial for understanding how AI can be leveraged to support healthcare professionals and improve patient outcomes in real-world scenarios.'],
#        dtype=object),
#  array(['ANPA2024-N00033', 'ANPA2024-N00032', 'ANPA2024-N00031',
#         'ANPA2024-N00030', 'ANPA2024-N00034', 'ANPA2024-N00035',
#         'ANPA2024-N00049', 'ANPA2024-N00050', 'ANPA2024-N00051'],
#        dtype=object),
#  ['2024/07/19 02:30 AM',
#   '2024/07/19 02:30 AM',
#   '2024/07/19 02:30 AM',
#   '2024/07/19 02:30 AM',
#   '2024/07/19 02:30 AM',
#   '2024/07/19 02:30 AM',
#   '2024/07/19 09:00 AM',
#   '2024/07/19 09:30 AM',
#   '2024/07/19 10:00 AM'],
#  ['2024/07/19 12:15 PM',
#   '2024/07/19 12:15 PM',
#   '2024/07/19 12:15 PM',
#   '2024/07/19 12:15 PM',
#   '2024/07/19 12:15 PM',
#   '2024/07/19 12:15 PM',
#   '2024/07/19 06:45 PM',
#   '2024/07/19 07:15 PM',
#   '2024/07/19 07:45 PM'],
#  array(['Poster Presentation', 'Poster Presentation',
#         'Poster Presentation', 'Poster Presentation',
#         'Poster Presentation', 'Poster Presentation',
#         'Virtual Presentation', 'Virtual Presentation',
#         'Virtual Presentation'], dtype=object))

# %%
def create_html(df_name,html_name):
    Names_L,affiliations_L,title_L,abstract_L,abstract_n_L,Date_L,Date_L_N, Location_L =prep_list(df_name)
    fo = open(html_name, 'w',encoding="utf-8")
    fo.write(prepend)
    fo = open(html_name, 'a+',encoding="utf-8")
    for i in range(len(Names_L)):

        names_ = Names_L[i]
        title_ = title_L[i]
        affil_ = affiliations_L[i]
        abstract_ = abstract_L[i]
        abstract_n_=abstract_n_L[i]
        date_=Date_L[i]
        nepaldate_=Date_L_N[i]
        location_ = Location_L[i]

        html_code = '''

        <!-- ########################################################################## -->

        <tr>
                    <td width="158" colspan="2">
                        <p> Date/Time: <br>
                            ET:&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;{date_} </br>
                            Nepal: {nepaldate_}
                        </p>
                    </td>

        <td width="521" colspan="6">
            <p>Abstract Number: {abstract_n_} </p>

            <p>Presenting Author: {names_}
            </p>

            <p>Presenter's Affiliation: {affil_}
            </p>

            <p><strong>Title: </strong>{title_}</a></p>

            <p> <strong>Location: </strong>{location_}</p>

            <p class="show_hide">Show/Hide Abstract</p>
            <div class="show_on_click">{abstract_}</div>

        </td>
        </tr>

    '''.format(date_=date_,nepaldate_=nepaldate_,abstract_n_=abstract_n_,affil_=affil_,names_=names_,
               title_ = title_,abstract_=abstract_,location_=location_)
        fo.write(html_code)

    fo = open(html_name, 'a+',encoding="utf-8")
    fo.write(postpend)
    fo.close()

# %%
# !ls
# Out:
# SortedSchedule.csv                      html_code_2024_Condensed.html
# date_sorted_schedule.csv                html_code_2024_Fayetteville.html
# date_sorted_schedule.xlsx               html_code_2024_HEP.html
# drive-download-20240706T150935Z-001.zip html_code_2024_PER.html
# gen_abstract_htmls_GK_072024.ipynb      html_code_2024_Plasma.html
# gen_abstract_htmls_final_2024.ipynb     html_code_2024_data.html
# html_code_2024_Applied.html             merged_v3.csv
# html_code_2024_Astro.html               merged_v4.xlsx
# html_code_2024_Bio.html                 testNabinHTML.ipynb
# html_code_2024_CDP.html                 testhtml24.csv

# %%
df_FSU.sort_values(by=["Date/Time"])
# Out:
#               presenter        method  \
# 79        Daniel Autrey  Fayetteville
# 80       Kenan Gundogdu  Fayetteville
# 81   Ghadendra Bhandari  Fayetteville
# 82         Basu Dev Oli  Fayetteville
# 83              Jett Wu  Fayetteville
# 85        Bhanu Ghimire  Fayetteville
# 86  Chandra M. Adhikari  Fayetteville
# 87       Dipendra Dahal  Fayetteville
# 88    Devi Lal Adhikari  Fayetteville
# 89  Trailokya Bhattarai  Fayetteville
# 90           Sanjib K C  Fayetteville
# 92     Chandra P. Joshi  Fayetteville
# 93         Umesh Silwal  Fayetteville
# 94        Nabin Malakar  Fayetteville
# 95          Bhoj Gautam  Fayetteville
# 96  Dr. Nisha H. Makani  Fayetteville
# 97        Pravin Sharma  Fayetteville
# 98      Tikaram Neupane  Fayetteville
#
#                                           affiliation manuscript  \
# 79                      Fayetteville State University         No
# 80                                NC State University         No
# 81                           West Virginia University        Yes
# 82  Department of Physics and Astronomy, West Virg...         No
# 83                      Fayetteville State University         No
# 85          University of North Caroline at Charlotte         No
# 86  Department of Chemistry, Physics and Materials...        Yes
# 87                                                NaN         No
# 88                                      Virginia Tech         No
# 89                                      UNC Charlotte         No
# 90                           Georgia State University         No
# 92          University of North Carolina at Asheville        Yes
# 93          University of North Carolina at Charlotte        Yes
# 94                         Worcester State University        Yes
# 95                      Fayetteville State University         No
# 96                      Fayetteville state university        Yes
# 97                                     William & Mary        Yes
# 98       The University of North Carolina at Pembroke        Yes
#
#                                              division  \
# 79                                            Welcome
# 80      Condensed Matter Physics and Material Science
# 81      Condensed Matter Physics and Material Science
# 82      Condensed Matter Physics and Material Science
# 83      Condensed Matter Physics and Material Science
# 85      Atomic, Molecular, Optical and Plasma Physics
# 86      Atomic, Molecular, Optical and Plasma Physics
# 87      Atomic, Molecular, Optical and Plasma Physics
# 88         High Energy, Particle, and Nuclear Physics
# 89  Biological, Medical, Soft Matter and Chemical ...
# 90  Astronomy /Space Science /Cosmo Science/ Atmos...
# 92                         Physics Education Research
# 93                         Physics Education Research
# 94  Astronomy /Space Science /Cosmo Science/ Atmos...
# 95      Condensed Matter Physics and Material Science
# 96      Condensed Matter Physics and Material Science
# 97      Condensed Matter Physics and Material Science
# 98      Condensed Matter Physics and Material Science
#
#                                                 title  \
# 79                Welcome message by Department Chair
# 80  Room Temperature Perovskite Superfluorescence ...
# 81  Study of spontaneous magnetization reversal in...
# 82  Determining alloy composition in superconducti...
# 83  Nano-Optimized Acetylcholinesterase Biosensor ...
# 85                     Meanderline Quarter Wave Plate
# 86  Effect of cavity length in Mxene-based Fabry P...
# 87  Resonance peak position tuning in Fabry Perot ...
# 88  Parity-Violating Electron Scattering as a Prob...
# 89  Advancing Disinfection Technology: Solar-Power...
# 90  Space Radiation in Earth Environment with Radi...
# 92  An Approach to Near Hundred Percent Success in...
# 93  Evidence-based Teaching Practices in Physics: ...
# 94  Information to Action Using Air Pollution data...
# 95  Gamma Radiation Induced Structural Changes in ...
# 96  Enhancing optical characteristics of Ti3C2 MXe...
# 97  Atomistic Investigation of Ultrafast demagneti...
# 98  Optical Properties of Cadmium Selenide Quantum...
#
#                                              abstract         Type Start Date  \
# 79                                                NaN      Welcome 2024-07-20
# 80  The formation of coherent macroscopic states a...      Plenary 2024-07-20
# 81  Manganite perovskite compounds have gained int...  Contributed 2024-07-20
# 82  Chemical pressure from the isovalent substitut...  Contributed 2024-07-20
# 83  Acetylcholinesterase (AChE) inhibitors, such a...  Contributed 2024-07-20
# 85  Meanderline grids are basically wave retarder ...  Contributed 2024-07-20
# 86  Fabry-Perot interferometers (FPIs) are optical...  Contributed 2024-07-20
# 87  Making use of Maxwell’s equation, we have deri...  Contributed 2024-07-20
# 88  Parity is a discrete transformation that rever...  Contributed 2024-07-20
# 89  UV-C radiation is effective in deactivating a ...  Contributed 2024-07-20
# 90  Monitoring and analyzing the radiation environ...  Contributed 2024-07-20
# 92  In this presentation, the results of teaching ...  Contributed 2024-07-20
# 93  Learning is inherently a social process as out...  Contributed 2024-07-20
# 94  We will present a case study of Nepal, where a...  Contributed 2024-07-20
# 95  High electronic conductivity, structural diver...  Contributed 2024-07-20
# 96  The remarkable capabilities of Ti3C2 MXene qua...  Contributed 2024-07-20
# 97  Permalloy (Ni80Fe20) is one of the soft ferrom...  Contributed 2024-07-20
# 98  The optical properties of Cadmium Selenide (Cd...  Contributed 2024-07-20
#
#    Start Time   End Date  End Time      abstract_id           Date/Time  \
# 79   08:45:00 2024-07-20  09:00:00  ANPA2024-N00080 2024-07-20 08:45:00
# 80   09:00:00 2024-07-20  10:00:00  ANPA2024-N00081 2024-07-20 09:00:00
# 81   10:00:00 2024-07-20  10:15:00  ANPA2024-N00082 2024-07-20 10:00:00
# 82   10:15:00 2024-07-20  10:30:00  ANPA2024-N00083 2024-07-20 10:15:00
# 83   10:30:00 2024-07-20  10:45:00  ANPA2024-N00084 2024-07-20 10:30:00
# 85   11:00:00 2024-07-20  11:15:00  ANPA2024-N00086 2024-07-20 11:00:00
# 86   11:15:00 2024-07-20  11:30:00  ANPA2024-N00087 2024-07-20 11:15:00
# 87   11:30:00 2024-07-20  11:45:00  ANPA2024-N00088 2024-07-20 11:30:00
# 88   11:45:00 2024-07-20  12:00:00  ANPA2024-N00089 2024-07-20 11:45:00
# 89   12:00:00 2024-07-20  12:15:00  ANPA2024-N00090 2024-07-20 12:00:00
# 90   12:15:00 2024-07-20  12:30:00  ANPA2024-N00091 2024-07-20 12:15:00
# 92   14:00:00 2024-07-20  14:15:00  ANPA2024-N00093 2024-07-20 14:00:00
# 93   14:15:00 2024-07-20  14:30:00  ANPA2024-N00094 2024-07-20 14:15:00
# 94   14:30:00 2024-07-20  14:45:00  ANPA2024-N00095 2024-07-20 14:30:00
# 95   14:45:00 2024-07-20  15:00:00  ANPA2024-N00096 2024-07-20 14:45:00
# 96   15:00:00 2024-07-20  15:15:00  ANPA2024-N00097 2024-07-20 15:00:00
# 97   15:15:00 2024-07-20  15:30:00  ANPA2024-N00098 2024-07-20 15:15:00
# 98   15:30:00 2024-07-20  15:45:00  ANPA2024-N00099 2024-07-20 15:30:00
#
#        Nepal Date/Time             Author_I  \
# 79 2024-07-20 18:30:00        Daniel Autrey
# 80 2024-07-20 18:45:00       Kenan Gundogdu
# 81 2024-07-20 19:45:00   Ghadendra Bhandari
# 82 2024-07-20 20:00:00         Basu Dev Oli
# 83 2024-07-20 20:15:00              Jett Wu
# 85 2024-07-20 20:45:00        Bhanu Ghimire
# 86 2024-07-20 21:00:00  Chandra M. Adhikari
# 87 2024-07-20 21:15:00       Dipendra Dahal
# 88 2024-07-20 21:30:00    Devi Lal Adhikari
# 89 2024-07-20 21:45:00  Trailokya Bhattarai
# 90 2024-07-20 22:00:00           Sanjib K C
# 92 2024-07-20 23:45:00     Chandra P. Joshi
# 93 2024-07-21 00:00:00         Umesh Silwal
# 94 2024-07-21 00:15:00        Nabin Malakar
# 95 2024-07-21 00:30:00          Bhoj Gautam
# 96 2024-07-21 00:45:00  Dr. Nisha H. Makani
# 97 2024-07-21 01:00:00        Pravin Sharma
# 98 2024-07-21 01:15:00      Tikaram Neupane
#
#                          CDP/FYT/Virtual
# 79  In-Person Presentation, Fayetteville
# 80  In-Person Presentation, Fayetteville
# 81  In-Person Presentation, Fayetteville
# 82  In-Person Presentation, Fayetteville
# 83  In-Person Presentation, Fayetteville
# 85  In-Person Presentation, Fayetteville
# 86  In-Person Presentation, Fayetteville
# 87  In-Person Presentation, Fayetteville
# 88  In-Person Presentation, Fayetteville
# 89  In-Person Presentation, Fayetteville
# 90  In-Person Presentation, Fayetteville
# 92  In-Person Presentation, Fayetteville
# 93  In-Person Presentation, Fayetteville
# 94  In-Person Presentation, Fayetteville
# 95  In-Person Presentation, Fayetteville
# 96  In-Person Presentation, Fayetteville
# 97  In-Person Presentation, Fayetteville
# 98  In-Person Presentation, Fayetteville

# %%
create_html(df_data,html_name='html_code_2024_data.html')
create_html(df_PER,html_name='html_code_2024_PER.html')
create_html(df_Condensed,html_name='html_code_2024_Condensed.html')
create_html(df_Bio,html_name='html_code_2024_Bio.html')
create_html(df_Plasma,html_name='html_code_2024_Plasma.html')
create_html(df_HEP,html_name='html_code_2024_HEP.html')
create_html(df_Applied,html_name='html_code_2024_Applied.html')
create_html(df_Astro,html_name='html_code_2024_Astro.html')

# Create HTML based on Location
create_html(df_CDP,html_name='html_code_2024_CDP.html')
create_html(df_FSU,html_name='html_code_2024_Fayetteville.html')

# %% [markdown]
# ## Create Calendar

# %%
df.dtypes
# Out:
# presenter                  object
# method                     object
# affiliation                object
# manuscript                 object
# division                   object
# title                      object
# abstract                   object
# Type                       object
# Start Date                 object
# Start Time                 object
# End Date                   object
# End Time                   object
# abstract_id                object
# Date/Time          datetime64[ns]
# Nepal Date/Time    datetime64[ns]
# Author_I                   object
# CDP/FYT/Virtual            object
# dtype: object

# %%
df['Start_DateTime']=df['Start Date'].astype(str)+' '+df['Start Time'].astype(str)
df['Start_DateTime'] = pd.to_datetime(df['Start_DateTime'],format=('%Y-%m-%d  %H:%M:%S'))
df['Start_DateTime'] = df['Start_DateTime'] #+ timedelta(hours=4)#.dt.tz_localize('UTC')#.dt.tz_convert('US/Eastern')

df['End_DateTime']=  df['End Date'].astype(str)+' '+df['End Time'].astype(str)
df['End_DateTime'] = pd.to_datetime(df['End_DateTime'],format=('%Y-%m-%d  %H:%M:%S'))
df['End_DateTime'] = df['End_DateTime'] #+ timedelta(hours=4)#.dt.tz_localize('UTC')#.dt.tz_convert('US/Eastern')#

# %%
def prep_list(df):
    Names_L= df['Author_I'].values
    title_L = df['title'].values
    Date_L=df['Start_DateTime'].values
    EndDate_L=df['End_DateTime'].values
    return Names_L,title_L,Date_L,EndDate_L

# %%
df[['Start_DateTime','End_DateTime','abstract_id',"title"]].sort_values(by="Start_DateTime")
# Out:
#          Start_DateTime        End_DateTime       abstract_id  \
# 91  2024-07-18 22:45:00 2024-07-18 23:00:00   ANPA2024-N00092
# 86  2024-07-18 23:00:00 2024-07-19 00:00:00   ANPA2024-N00087
# 115 2024-07-19 00:00:00 2024-07-19 00:15:00  ANPA2024-N000116
# 125 2024-07-19 00:15:00 2024-07-19 00:30:00  ANPA2024-N000126
# 39  2024-07-19 00:30:00 2024-07-19 00:45:00   ANPA2024-N00040
# ..                  ...                 ...               ...
# 103 2024-07-21 10:00:00 2024-07-21 10:15:00  ANPA2024-N000104
# 132 2024-07-21 10:15:00 2024-07-21 10:30:00  ANPA2024-N000133
# 73  2024-07-21 10:45:00 2024-07-21 11:15:00   ANPA2024-N00074
# 44  2024-07-21 11:15:00 2024-07-21 11:30:00   ANPA2024-N00045
# 97  2024-07-21 11:30:00 2024-07-21 11:45:00   ANPA2024-N00098
#
#                                                  title
# 91                 Welcome message by Department Chair
# 86   Space Weather at Low-Latitudes and Prospects o...
# 115  Development and Characterization of Gliding Ar...
# 125  Electrical and Optical Characterization of Kni...
# 39   Attenuation of Photons, Neutrons, and Heavy Io...
# ..                                                 ...
# 103                         Space travel SST 6 Mission
# 132  Solar wind turbulence anisotropy evolution in ...
# 73   Physicist's Journey to Machine Learning Fraud ...
# 44   Can AI Solve Physics Problems? Evaluating Effi...
# 97   Comparative Analysis of ChatGPT, Bard, and LLa...
#
# [138 rows x 4 columns]

# %%
df['diff'] = (df['End_DateTime'] - df['Start_DateTime']).dt.days
df['diff'].value_counts()
# Out:
# 0    138
# Name: diff, dtype: int64

# %%
df.loc[df['diff']==-1]
# Out:
# Empty DataFrame
# Columns: [presenter, method, affiliation, manuscript, division, title, abstract, Type, Start Date, Start Time, End Date, End Time, abstract_id, Date/Time, Nepal Date/Time, Author_I, CDP/FYT/Virtual, Start_DateTime, End_DateTime, diff]
# Index: []

# %%
c=Calendar()
Names_L,title_L,Date_L,EndDate_L=prep_list(df)
str(Date_L[0])
for i in range(len(Names_L)):
    e=Event()
    e.name=Names_L[i]
    e.begin=str(Date_L[i])
    e.end=str(EndDate_L[i])
    e.description=title_L[i]
    c.events.add(e)
c.events
# Out:
# {<Event 'Om Prakash Niroula' begin:2024-07-18T22:45:00+00:00 end:2024-07-18T23:00:00+00:00>,
#  <Event 'Narayan Prasad Chapagain, PhD' begin:2024-07-18T23:00:00+00:00 end:2024-07-19T00:00:00+00:00>,
#  <Event 'Roshan Chalise' begin:2024-07-19T00:00:00+00:00 end:2024-07-19T00:15:00+00:00>,
#  <Event 'Santosh Dhungana' begin:2024-07-19T00:15:00+00:00 end:2024-07-19T00:30:00+00:00>,
#  <Event 'Devendra Raj Upadhyay' begin:2024-07-19T00:30:00+00:00 end:2024-07-19T00:45:00+00:00>,
#  <Event 'Bed Prasad Pandey' begin:2024-07-19T01:00:00+00:00 end:2024-07-19T01:15:00+00:00>,
#  <Event 'Santosh Kumar Pandit' begin:2024-07-19T01:15:00+00:00 end:2024-07-19T01:30:00+00:00>,
#  <Event 'Saddam Husain Dhobi' begin:2024-07-19T01:30:00+00:00 end:2024-07-19T01:45:00+00:00>,
#  <Event 'LEO DYAJI' begin:2024-07-19T01:45:00+00:00 end:2024-07-19T02:00:00+00:00>,
#  <Event 'Hari Shankar Mallik' begin:2024-07-19T02:00:00+00:00 end:2024-07-19T02:15:00+00:00>,
#  <Event 'Narayan Gautam' begin:2024-07-19T02:15:00+00:00 end:2024-07-19T02:30:00+00:00>,
#  <Event 'Meenashree Khanal' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Aman Kumar Rai' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Aatiz Ghimire' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Saroj Pandeya' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Kedar Nath Jaiswal' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Bikal Khanal' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Sabita Pandey' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Dikshya Chand' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Pawan Joshi' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Gokarna Banjade' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Samjhana Dahal' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Dipak Oli' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Pratima Khadka' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Manisha Rai' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Ambika Shahi' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Pratiksha Khanal' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Nisha Kaucha' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'BINAYA CHANDRA POKHREL' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Damodar Neupane' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Keshab Chaudhary, Dipendra Prasad Kalauni' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Kashi Ram Panday' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Ramesh Khanal' begin:2024-07-19T02:30:00+00:00 end:2024-07-19T04:00:00+00:00>,
#  <Event 'Chiranjib Mitra (Invited)' begin:2024-07-19T04:00:00+00:00 end:2024-07-19T04:30:00+00:00>,
#  <Event 'Deergh Bahadur Shahi' begin:2024-07-19T04:30:00+00:00 end:2024-07-19T04:45:00+00:00>,
#  <Event 'Dipak Bhattarai' begin:2024-07-19T04:45:00+00:00 end:2024-07-19T05:00:00+00:00>,
#  <Event 'Mithilesh Kumar Jha' begin:2024-07-19T05:00:00+00:00 end:2024-07-19T05:15:00+00:00>,
#  <Event 'Sarita Lawaju' begin:2024-07-19T05:15:00+00:00 end:2024-07-19T05:30:00+00:00>,
#  <Event 'Ram Prasad Regmi (Invited)' begin:2024-07-19T05:45:00+00:00 end:2024-07-19T06:15:00+00:00>,
#  <Event 'Lok Nath Sharma' begin:2024-07-19T06:15:00+00:00 end:2024-07-19T06:30:00+00:00>,
#  <Event 'Madhu Sudan Paudel' begin:2024-07-19T06:30:00+00:00 end:2024-07-19T06:45:00+00:00>,
#  <Event 'Prakash Man Shrestha' begin:2024-07-19T06:45:00+00:00 end:2024-07-19T07:00:00+00:00>,
#  <Event 'Purna Jyoti Shakya' begin:2024-07-19T07:00:00+00:00 end:2024-07-19T07:15:00+00:00>,
#  <Event 'Sanjay Lal Karna' begin:2024-07-19T07:15:00+00:00 end:2024-07-19T07:30:00+00:00>,
#  <Event 'Ganapathi Subramania (Invited)' begin:2024-07-19T09:00:00+00:00 end:2024-07-19T09:30:00+00:00>,
#  <Event 'Abdul Klam Khan' begin:2024-07-19T09:30:00+00:00 end:2024-07-19T09:45:00+00:00>,
#  <Event 'N. Rama Devi' begin:2024-07-19T10:00:00+00:00 end:2024-07-19T10:15:00+00:00>,
#  <Event 'Rudra KAFLE (Invited)' begin:2024-07-19T11:00:00+00:00 end:2024-07-19T11:30:00+00:00>,
#  <Event 'Bir Bohara' begin:2024-07-19T11:30:00+00:00 end:2024-07-19T11:45:00+00:00>,
#  <Event 'Chandra M. Adhikari' begin:2024-07-19T11:45:00+00:00 end:2024-07-19T12:00:00+00:00>,
#  <Event 'Ganga Sharma' begin:2024-07-19T12:00:00+00:00 end:2024-07-19T12:15:00+00:00>,
#  <Event 'Rajan Ghimire' begin:2024-07-19T12:15:00+00:00 end:2024-07-19T12:30:00+00:00>,
#  <Event 'Richard' begin:2024-07-19T12:30:00+00:00 end:2024-07-19T12:45:00+00:00>,
#  <Event 'Binod K Rai (Invited)' begin:2024-07-19T14:00:00+00:00 end:2024-07-19T14:30:00+00:00>,
#  <Event 'Milo Xavier Sprague' begin:2024-07-19T14:30:00+00:00 end:2024-07-19T14:45:00+00:00>,
#  <Event 'Nathan Valadez' begin:2024-07-19T14:45:00+00:00 end:2024-07-19T15:00:00+00:00>,
#  <Event 'Iftakhar Bin Elius' begin:2024-07-19T15:00:00+00:00 end:2024-07-19T15:15:00+00:00>,
#  <Event 'Tej Nath Lamichhane' begin:2024-07-19T15:15:00+00:00 end:2024-07-19T15:30:00+00:00>,
#  <Event 'Mohamed El Gazzah' begin:2024-07-19T15:30:00+00:00 end:2024-07-19T15:45:00+00:00>,
#  <Event 'Resham B Regmi' begin:2024-07-19T15:45:00+00:00 end:2024-07-19T16:00:00+00:00>,
#  <Event 'Gabriel Kinney' begin:2024-07-19T16:45:00+00:00 end:2024-07-19T17:00:00+00:00>,
#  <Event 'Yamuna Paudel' begin:2024-07-19T17:00:00+00:00 end:2024-07-19T17:15:00+00:00>,
#  <Event 'Saniya L. Lyles' begin:2024-07-19T17:15:00+00:00 end:2024-07-19T17:30:00+00:00>,
#  <Event 'Christopher Kai Addaman' begin:2024-07-19T17:30:00+00:00 end:2024-07-19T17:45:00+00:00>,
#  <Event 'Talon David Alexander' begin:2024-07-19T17:45:00+00:00 end:2024-07-19T18:00:00+00:00>,
#  <Event 'Jittin V Thoms' begin:2024-07-19T18:00:00+00:00 end:2024-07-19T18:15:00+00:00>,
#  <Event 'Sekh Jamaluddin' begin:2024-07-19T18:30:00+00:00 end:2024-07-19T18:45:00+00:00>,
#  <Event 'Abhijeet Nayak' begin:2024-07-19T18:45:00+00:00 end:2024-07-19T19:00:00+00:00>,
#  <Event 'Hari Bhandari' begin:2024-07-19T19:00:00+00:00 end:2024-07-19T19:15:00+00:00>,
#  <Event 'Supriya Dhakal' begin:2024-07-19T19:15:00+00:00 end:2024-07-19T19:30:00+00:00>,
#  <Event 'Suresh Gnawali' begin:2024-07-19T19:30:00+00:00 end:2024-07-19T19:45:00+00:00>,
#  <Event 'Tika R Kafle' begin:2024-07-19T19:45:00+00:00 end:2024-07-19T20:00:00+00:00>,
#  <Event 'Laxmi khatiwada' begin:2024-07-19T21:30:00+00:00 end:2024-07-19T21:45:00+00:00>,
#  <Event 'Poojan Koirala' begin:2024-07-19T21:45:00+00:00 end:2024-07-19T22:00:00+00:00>,
#  <Event 'Sudhan Koirala' begin:2024-07-19T22:00:00+00:00 end:2024-07-19T22:15:00+00:00>,
#  <Event 'Karan Giri' begin:2024-07-19T22:30:00+00:00 end:2024-07-19T22:45:00+00:00>,
#  <Event 'Laxman Chaudhary' begin:2024-07-19T22:45:00+00:00 end:2024-07-19T23:00:00+00:00>,
#  <Event 'Bhupendra Sharma' begin:2024-07-19T23:00:00+00:00 end:2024-07-19T23:15:00+00:00>,
#  <Event 'Prakash Khatri' begin:2024-07-19T23:15:00+00:00 end:2024-07-19T23:30:00+00:00>,
#  <Event 'Pankaj Singh Dhami' begin:2024-07-19T23:30:00+00:00 end:2024-07-19T23:45:00+00:00>,
#  <Event 'Krishna Bahadur Rai' begin:2024-07-19T23:45:00+00:00 end:2024-07-20T00:00:00+00:00>,
#  <Event 'Mehmood Pirzada' begin:2024-07-20T00:00:00+00:00 end:2024-07-20T00:15:00+00:00>,
#  <Event 'Daniel Autrey' begin:2024-07-20T08:45:00+00:00 end:2024-07-20T09:00:00+00:00>,
#  <Event 'Kenan Gundogdu' begin:2024-07-20T09:00:00+00:00 end:2024-07-20T10:00:00+00:00>,
#  <Event 'Ghadendra Bhandari' begin:2024-07-20T10:00:00+00:00 end:2024-07-20T10:15:00+00:00>,
#  <Event 'Basu Dev Oli' begin:2024-07-20T10:15:00+00:00 end:2024-07-20T10:30:00+00:00>,
#  <Event 'Jett Wu' begin:2024-07-20T10:30:00+00:00 end:2024-07-20T10:45:00+00:00>,
#  <Event 'Bhanu Ghimire' begin:2024-07-20T11:00:00+00:00 end:2024-07-20T11:15:00+00:00>,
#  <Event 'Chandra M. Adhikari' begin:2024-07-20T11:15:00+00:00 end:2024-07-20T11:30:00+00:00>,
#  <Event 'Dipendra Dahal' begin:2024-07-20T11:30:00+00:00 end:2024-07-20T11:45:00+00:00>,
#  <Event 'Devi Lal Adhikari' begin:2024-07-20T11:45:00+00:00 end:2024-07-20T12:00:00+00:00>,
#  <Event 'Trailokya Bhattarai' begin:2024-07-20T12:00:00+00:00 end:2024-07-20T12:15:00+00:00>,
#  <Event 'Sanjib K C' begin:2024-07-20T12:15:00+00:00 end:2024-07-20T12:30:00+00:00>,
#  <Event 'Chandra P. Joshi' begin:2024-07-20T14:00:00+00:00 end:2024-07-20T14:15:00+00:00>,
#  <Event 'Umesh Silwal' begin:2024-07-20T14:15:00+00:00 end:2024-07-20T14:30:00+00:00>,
#  <Event 'Nabin Malakar' begin:2024-07-20T14:30:00+00:00 end:2024-07-20T14:45:00+00:00>,
#  <Event 'Bhoj Gautam' begin:2024-07-20T14:45:00+00:00 end:2024-07-20T15:00:00+00:00>,
#  <Event 'Dr. Nisha H. Makani' begin:2024-07-20T15:00:00+00:00 end:2024-07-20T15:15:00+00:00>,
#  <Event 'Pravin Sharma' begin:2024-07-20T15:15:00+00:00 end:2024-07-20T15:30:00+00:00>,
#  <Event 'Tikaram Neupane' begin:2024-07-20T15:30:00+00:00 end:2024-07-20T15:45:00+00:00>,
#  <Event 'Krishna K C' begin:2024-07-20T18:00:00+00:00 end:2024-07-20T18:15:00+00:00>,
#  <Event 'Sadhana Vattikuti' begin:2024-07-20T18:15:00+00:00 end:2024-07-20T18:30:00+00:00>,
#  <Event 'Raj Kumar Paudel' begin:2024-07-20T18:30:00+00:00 end:2024-07-20T18:45:00+00:00>,
#  <Event 'Anup Pradhan Sakhya' begin:2024-07-20T18:45:00+00:00 end:2024-07-20T19:00:00+00:00>,
#  <Event 'Arun Kumar Kumay' begin:2024-07-20T19:00:00+00:00 end:2024-07-20T19:15:00+00:00>,
#  <Event 'Mazharul Islam Mondal' begin:2024-07-20T19:15:00+00:00 end:2024-07-20T19:30:00+00:00>,
#  <Event 'Chuyu Liu (Invited)' begin:2024-07-20T19:45:00+00:00 end:2024-07-20T20:15:00+00:00>,
#  <Event 'Shruti Shrestha' begin:2024-07-20T20:15:00+00:00 end:2024-07-20T20:30:00+00:00>,
#  <Event 'Bhawin Dhital' begin:2024-07-20T20:30:00+00:00 end:2024-07-20T20:45:00+00:00>,
#  <Event 'Sushil Kumar Sedhai' begin:2024-07-20T20:45:00+00:00 end:2024-07-20T21:00:00+00:00>,
#  <Event 'Ganesh Chand (Invited)' begin:2024-07-20T21:30:00+00:00 end:2024-07-20T22:00:00+00:00>,
#  <Event 'Chandrama Mukherjee' begin:2024-07-20T22:00:00+00:00 end:2024-07-20T22:15:00+00:00>,
#  <Event 'Navdeep Kalkat' begin:2024-07-20T22:15:00+00:00 end:2024-07-20T22:30:00+00:00>,
#  <Event 'Anup Shrestha' begin:2024-07-20T22:45:00+00:00 end:2024-07-20T23:00:00+00:00>,
#  <Event 'Pushpa Raj Pudasaini (Invited)' begin:2024-07-20T22:45:00+00:00 end:2024-07-20T23:15:00+00:00>,
#  <Event 'Roshan Pudasaini' begin:2024-07-20T23:00:00+00:00 end:2024-07-20T23:15:00+00:00>,
#  <Event 'Sunil Koju' begin:2024-07-20T23:15:00+00:00 end:2024-07-20T23:30:00+00:00>,
#  <Event 'Kalpana Gyawali' begin:2024-07-20T23:15:00+00:00 end:2024-07-20T23:30:00+00:00>,
#  <Event 'RAJESH MAHARJAN' begin:2024-07-20T23:30:00+00:00 end:2024-07-20T23:45:00+00:00>,
#  <Event 'Tej Nath Lamichhane' begin:2024-07-20T23:30:00+00:00 end:2024-07-20T23:45:00+00:00>,
#  <Event 'Anjan Dahal' begin:2024-07-20T23:45:00+00:00 end:2024-07-21T00:00:00+00:00>,
#  <Event 'BASANTA KUMAR RAJBANSHI' begin:2024-07-20T23:45:00+00:00 end:2024-07-21T00:00:00+00:00>,
#  <Event 'Nawal K. Khadka' begin:2024-07-21T08:45:00+00:00 end:2024-07-21T09:00:00+00:00>,
#  <Event 'Pradip Poudel' begin:2024-07-21T08:45:00+00:00 end:2024-07-21T09:00:00+00:00>,
#  <Event 'Preston Hazen' begin:2024-07-21T09:00:00+00:00 end:2024-07-21T09:15:00+00:00>,
#  <Event 'Aayush Gautam' begin:2024-07-21T09:00:00+00:00 end:2024-07-21T09:15:00+00:00>,
#  <Event 'Bhairab Ale' begin:2024-07-21T09:15:00+00:00 end:2024-07-21T09:30:00+00:00>,
#  <Event 'Krishna Sigdel' begin:2024-07-21T09:15:00+00:00 end:2024-07-21T09:30:00+00:00>,
#  <Event 'Bishwas L. Shrestha' begin:2024-07-21T09:30:00+00:00 end:2024-07-21T09:45:00+00:00>,
#  <Event 'Beyza Bektasoglu' begin:2024-07-21T09:30:00+00:00 end:2024-07-21T09:45:00+00:00>,
#  <Event 'Ganga Sharma' begin:2024-07-21T09:45:00+00:00 end:2024-07-21T10:00:00+00:00>,
#  <Event 'Nabin Gurung' begin:2024-07-21T09:45:00+00:00 end:2024-07-21T10:00:00+00:00>,
#  <Event 'Amba Datt Pant' begin:2024-07-21T10:00:00+00:00 end:2024-07-21T10:15:00+00:00>,
#  <Event 'Prem kumari katwal' begin:2024-07-21T10:00:00+00:00 end:2024-07-21T10:15:00+00:00>,
#  <Event 'Sujan Prasad Gautam' begin:2024-07-21T10:15:00+00:00 end:2024-07-21T10:30:00+00:00>,
#  <Event 'Madan Lamichhane, PhD (Invited)' begin:2024-07-21T10:45:00+00:00 end:2024-07-21T11:15:00+00:00>,
#  <Event 'Dipak Rimal and Puskar Chapagain' begin:2024-07-21T11:15:00+00:00 end:2024-07-21T11:30:00+00:00>,
#  <Event 'Prajwol Lamichhane' begin:2024-07-21T11:30:00+00:00 end:2024-07-21T11:45:00+00:00>}

# %%
with open('ANPA Conference Calendar 2023.ics', 'w', encoding="utf-8") as f:
    f.write(str(c))
# Out:
# C:\Users\plasm\AppData\Roaming\Python\Python39\site-packages\ics\component.py:85: FutureWarning: Behaviour of str(Component) will change in version 0.9 to only return a short description, NOT the ics representation. Use the explicit Component.serialize() to get the ics representation.
#   warnings.warn(
